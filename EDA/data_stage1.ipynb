# %%
# %matplotlib widget
# Out:
# [2023-05-22 14:09:24] [DEBU] Loaded backend module://ipympl.backend_nbagg version unknown.

# %%
import sys
sys.path.append("../")
from part_assembly import DatasetStage1

import logging
logging.getLogger().setLevel(logging.INFO)

# %%
datafolder = "/data/wlsgur4011/DataCollection/BreakingBad/data_split/"
artifact_val = f"{datafolder}artifact.val.pth"
dataset = DatasetStage1(artifact_val)

# %%
len(dataset)
# Out:
# 17686

# %%
idx = 1
data = dataset[idx]
sample = data['sample']
broken_label = data['broken_label']

# %%
from jhutil import show_point_clouds
show_point_clouds([sample[broken_label.logical_not()], sample[broken_label]])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import jhutil; jhutil.jhprint(1111, dataset[0])
# Out:
# [2023-05-22 14:09:28] [DEBU] handle_msg[ca2a8489dae44824bf95392b78bc2076]({'header': {'date': datetime.datetime(2023, 5, 22, 14, 9, 28, 590000, tzinfo=tzutc()), 'msg_id': '652c633b-0e9e-418a-b46c-0e1ee7723177', 'msg_type': 'comm_msg', 'session': 'd6b7c64a-0ad0-4147-adfb-ffda491808b9', 'username': '', 'version': '5.2'}, 'msg_id': '652c633b-0e9e-418a-b46c-0e1ee7723177', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'ca2a8489dae44824bf95392b78bc2076', 'data': {'method': 'custom', 'content': {'type': 'refresh'}}}, 'buffers': []})
# ...
